# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.model import predict_demand

print(predict_demand(100))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from src.model import predict_demand
#       3 print(predict_demand(100))
#
# ImportError: cannot import name 'predict_demand' from 'src.model' (/Users/zeneta/SmartGridAI/src/model.py)

# %%
import importlib
import src.model

importlib.reload(src.model)

# %%
# !pip3 install pandas

# %%
import pandas as pd
print(pd.__version__)

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

import pandas as pd

df = pd.read_csv("../data/demand.csv")
df.head()

# %%
# !pwd

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import numpy as np
from src.model import train_model, predict

X = np.array([[1], [2], [3], [4]])
y = np.array([100, 150, 200, 250])

model = train_model(X, y)

prediction = predict(model, [[5]])
print("Prediction:", prediction)

# %%
# !ls ..

# %%
# !ls ../data

# %%
import pandas as pd

df = pd.read_csv("../data/demand.csv")
df.head()

# %%
import matplotlib.pyplot as plt

plt.plot(df["time"], df["consumption"])
plt.title("Daily Electricity Demand")
plt.xlabel("Time (Hours)")
plt.ylabel("Consumption")
plt.show()

# %%
import pandas as pd
import numpy as np

# Generate data
time = np.arange(1, 1001)
consumption = 100 + 0.5*time + np.random.randint(-20, 20, size=1000)

df = pd.DataFrame({
    "time": time,
    "consumption": consumption
})

# Save to CSV
df.to_csv("../data/demand_large.csv", index=False)

df.head()

# %%
from src.model import train_model, predict
import pandas as pd

df = pd.read_csv("../data/demand_large.csv")

X = df[["time"]]
y = df["consumption"]

model = train_model(X, y)

# FIX here
future = pd.DataFrame([[1100]], columns=["time"])
prediction = predict(model, future)

print("Future Demand Prediction:", prediction)

# %%
import matplotlib.pyplot as plt

predicted = model.predict(X)

plt.plot(df["time"], df["consumption"], label="Actual")
plt.plot(df["time"], predicted, label="Predicted")

plt.legend()
plt.title("SmartGridAI Model Performance")
plt.show()

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
# !ls ../src

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

print(sys.path)  # optional check

# %%
from src.alerts import high_demand_alert
print("Import successful")

# %%
# !pwd

# %%
# !ls ..

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd
from src.model import train_model, predict

# Load data
df = pd.read_csv("../data/demand_large.csv")

# Train
X = df[["time"]]
y = df["consumption"]

model = train_model(X, y)

# FIX: create prediction again
future = pd.DataFrame([[1100]], columns=["time"])
prediction = predict(model, future)

print("Prediction:", prediction)

# %%
from src.alerts import high_demand_alert

threshold = 600

if high_demand_alert(prediction[0], threshold):
    print("⚠️ HIGH DEMAND ALERT!")
else:
    print("✅ Demand is normal")
